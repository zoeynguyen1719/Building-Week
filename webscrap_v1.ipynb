# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
def scrap(url_with_page_is_equal):

# %%
def get_list_pages_of_10(url_list_10):
    url_list = []
    for page_number in range(0,11):
        #remember that the end is ?page=
        url_page = url_list_10+str(page_number)
        url_list.append(url_page)
    return url_list

# %%
list_of_10pages = get_list_pages_of_10('https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=')

# %%
print(list_of_10pages)
# Out:
# ['https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=0', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=1', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=2', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=3', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=4', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=5', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=6', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=7', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=8', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=9', 'https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=10']

# %%
def get_links_for_100(url_one_page):
    url_page = requests.get(url_one_page)
    soup = BeautifulSoup(url_page.content, 'html.parser')
    href_link_list =[]
    for link in soup.find_all('a', class_='bookTitle') :
        if link.has_attr('href'):
            href_link_list.append(link.attrs['href'])
    return href_link_list

# %%
list_of_100_links = get_links_for_100('https://www.goodreads.com/list/show/6.Best_Books_of_the_20th_Century?page=1')

# %%
print(len(list_of_100_links))
print(list_of_100_links[0])
# Out:
# 100
# /book/show/2657.To_Kill_a_Mockingbird

# %%
dummy_test = []
for i in range(0,100):
    url_detail = "https://www.goodreads.com" + str(list_of_100_links[i])
    #soup_detail = BeautifulSoup(url_detail.content, 'html.parser')
    dummy_test.append(url_detail)

print(dummy_test)
# Out:
# ['https://www.goodreads.com/book/show/92364.Eye_of_the_Needle', 'https://www.goodreads.com/book/show/12995.The_Hamlet', 'https://www.goodreads.com/book/show/92160.London', 'https://www.goodreads.com/book/show/5191.The_Pilot_s_Wife', 'https://www.goodreads.com/book/show/55428.Goodbye_to_All_That', 'https://www.goodreads.com/book/show/10009.Homo_Faber', 'https://www.goodreads.com/book/show/77773.To_Say_Nothing_of_the_Dog', 'https://www.goodreads.com/book/show/588234.Ceremony', 'https://www.goodreads.com/book/show/77394.Anne_s_House_of_Dreams', 'https://www.goodreads.com/book/show/109830.Man_s_Fate', 'https://www.goodreads.com/book/show/9912.The_Rules_of_Attraction', 'https://www.goodreads.com/book/show/50.Hatchet', 'https://www.goodreads.com/book/show/9915.Less_Than_Zero', 'https://www.goodreads.com/book/show/47212.Storm_Front', 'https://www.goodreads.com/book/show/85448.The_Great_Santini', 'https://www.goodreads.com/book/show/11466.This_Boy_s_Life', 'https://www.goodreads.com/book/show/4747871-mrs-mike', 'https://www.goodreads.com/book/show/4339.Dispatches', 'https://www.goodreads.com/book/show/28877.Red_Dragon', 'https://www.goodreads.com/book/show/52251.Claudius_the_God_and_His_Wife_Messalina', 'https://www.goodreads.com/book/show/243381.Berlin_Alexanderplatz', 'https://www.goodreads.com/book/show/9605.Cat_s_Cradle_God_Bless_You_Mr_Rosewater_Breakfast_of_Champions', 'https://www.goodreads.com/book/show/119829.The_Sunne_in_Splendour', 'https://www.goodreads.com/book/show/34897.The_Dragon_Reborn', 'https://www.goodreads.com/book/show/65840.Anne_of_Windy_Poplars', 'https://www.goodreads.com/book/show/12287.Endgame', 'https://www.goodreads.com/book/show/52783.Henderson_the_Rain_King', 'https://www.goodreads.com/book/show/189783.The_Elfstones_of_Shannara', 'https://www.goodreads.com/book/show/1677.Sobre_h_roes_y_tumbas', 'https://www.goodreads.com/book/show/48862.Brighton_Rock', 'https://www.goodreads.com/book/show/10605.Thinner', 'https://www.goodreads.com/book/show/92417.The_Thin_Red_Line', 'https://www.goodreads.com/book/show/8822.Earthly_Powers', 'https://www.goodreads.com/book/show/85391.Rabbit_Is_Rich', 'https://www.goodreads.com/book/show/50051.The_Last_Picture_Show', 'https://www.goodreads.com/book/show/31338.Memnoch_the_Devil', 'https://www.goodreads.com/book/show/100933.That_Hideous_Strength', 'https://www.goodreads.com/book/show/77430.Master_and_Commander', 'https://www.goodreads.com/book/show/28547.Dragonsinger', 'https://www.goodreads.com/book/show/672948.Arch_of_Triumph', 'https://www.goodreads.com/book/show/659469.The_Hobbit', 'https://www.goodreads.com/book/show/90619.Little_Big', 'https://www.goodreads.com/book/show/114282.The_Littlest_Angel', 'https://www.goodreads.com/book/show/531262.A_Handful_of_Dust', 'https://www.goodreads.com/book/show/34517.Reaper_Man', 'https://www.goodreads.com/book/show/159582.The_Yearling', 'https://www.goodreads.com/book/show/1627.Brokeback_Mountain', 'https://www.goodreads.com/book/show/12096.Rhinoceros_The_Chairs_The_Lesson', 'https://www.goodreads.com/book/show/2270120.Dollanganger_Boxed_Set', 'https://www.goodreads.com/book/show/1431.Veronika_Decides_to_Die', 'https://www.goodreads.com/book/show/11389.Arrowsmith', 'https://www.goodreads.com/book/show/328854.Motherless_Brooklyn', 'https://www.goodreads.com/book/show/44796.The_Moon_and_Sixpence', 'https://www.goodreads.com/book/show/34497.The_Color_of_Magic', 'https://www.goodreads.com/book/show/77449.Here_Be_Dragons', 'https://www.goodreads.com/book/show/600335.The_Dollmaker', 'https://www.goodreads.com/book/show/25200.Silence', 'https://www.goodreads.com/book/show/130115.The_Grass_Is_Singing', 'https://www.goodreads.com/book/show/19312.The_Brothers_Lionheart', 'https://www.goodreads.com/book/show/61179.Ringworld', 'https://www.goodreads.com/book/show/136096.If_Not_Now_When_', 'https://www.goodreads.com/book/show/165395.Rubyfruit_Jungle', 'https://www.goodreads.com/book/show/219919.The_Robe', 'https://www.goodreads.com/book/show/72 ...

# %%
title = []
author = []
num_reviews = []
num_ratings = []
avg_rating = []
num_pages = []
original_publish_year = []

series = []

genres = []
awards = []

places = []

for link in dummy_test:
    one_book= requests.get(link)
    soup_detail = BeautifulSoup(one_book.content, 'html.parser')
    
    ####
    title.append(get_title(soup_detail))
    author.append(get_author(soup_detail))
    num_reviews.append(get_review(soup_detail))
    num_ratings.append(get_rating(soup_detail))
    avg_rating.append(get_avgrating(soup_detail))
    num_pages.append(get_page(soup_detail))
    original_publish_year.append(get_year(soup_detail))
    
    genres.append(get_genres(soup_detail))
    awards.append(get_award(soup_detail))
    

print(title)

# %%
data = {'title': title, 
      'author': author, 
      'num_reviews': num_reviews, 
      'num_ratings': num_ratings,
      'avg_rating': avg_rating,
      'num_pages':   num_pages,
      'original_publish_year': original_publish_year,
      'genres': genres,
      'awards': awards
      
     }

df = pd.DataFrame(data)

df.to_csv("df_first_100.csv", index=False)

# %%
df
# Out:
#                             title                                author  \
# 0               Eye of the Needle        Ken Follett (Goodreads Author)
# 1                      The Hamlet                      William Faulkner
# 2                          London  Edward Rutherfurd (Goodreads Author)
# 3                The Pilot's Wife                          Anita Shreve
# 4             Goodbye to All That                         Robert Graves
# ..                            ...                                   ...
# 95      The Milagro Beanfield War                      John     Nichols
# 96  The Lottery and Other Stories                       Shirley Jackson
# 97           The Last Enchantment                         Mary  Stewart
# 98                 Riddley Walker                         Russell Hoban
# 99       The Street of Crocodiles                        Bruno Schulz,
#
#      num_reviews num_ratings avg_rating num_pages original_publish_year  \
# 0   3,062reviews   [134,255]       4.19       339                  1978
# 1     282reviews     [4,792]       3.86       409                  1940
# 2   1,674reviews    [27,684]       4.06      1152                  1997
# 3   4,544reviews    [92,812]       3.54       304                  1998
# 4     680reviews    [13,076]       3.92       281                  1929
# ..           ...         ...        ...       ...                   ...
# 95    468reviews     [9,932]       4.09       456                  1974
# 96  2,562reviews    [65,746]       4.06       302                  1949
# 97    429reviews    [14,561]       4.17       513                  1979
# 98    833reviews     [7,171]       4.02       256                  1980
# 99    628reviews     [7,249]       4.12       160                  1933
#
#                                            genres  \
# 0                 [Fiction, Thriller, Historical]
# 1                 [Fiction, Classics, Literature]
# 2       [Historical, Historical Fiction, Fiction]
# 3            [Fiction, Womens Fiction, Chick Lit]
# 4                [Nonfiction, History, Biography]
# ..                                            ...
# 95         [Fiction, Magical Realism, Historical]
# 96               [Short Stories, Fiction, Horror]
# 97                 [Fantasy, Fiction, Historical]
# 98        [Fiction, Science Fiction, Apocalyptic]
# 99  [Fiction, Short Stories, European Literature]
#
#                                                awards
# 0                   Edgar Award for Best Novel (1979)
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                   NMBA Richard Harris Award (2018)
# 96                                                NaN
# 97  Locus Award Nominee for Best Fantasy Novel (1980)
# 98  Nebula Award Nominee for Best Novel (1982), Jo...
# 99  Prix du Meilleur Livre Étranger for Roman (197...
#
# [100 rows x 9 columns]

# %%
def get_title(soup_detail):
    try:
        title = soup_detail.find("h1", {"id":"bookTitle"}).text.replace("\n","").replace("      ","")
    except:
        title = np.nan
    return title



#get the book author

def get_author(soup_detail):
    try:
        author = soup_detail.find("div", {"class":"authorName__container"}).text.replace("\n","")
    except:
        author = np.nan
    return author





# get ratings

def get_rating(soup_detail):
    try:
        rating = soup_detail.find("meta", {"itemprop":"ratingCount"}).text.replace("\n","").split()
        rating = rating[0]        
    except:
        rating = np.nan      
    return rating


# get avgratings
book_avgratings = []
def get_avgrating(soup_detail):
    try:
        avgrating = soup_detail.find("span", {"itemprop":"ratingValue"}).text.replace("\n","").replace(' ','')
    except:
        avgrating = np.nan
    return avgrating

# get pages
book_pages = []
def get_page(soup_detail):
    try:
        page = soup_detail.find("span", {"itemprop":"numberOfPages"}).text.split()
        page = page[0]
    except:
        page = np.nan
    return page


# get years
book_publish_year = []
def get_year(soup_detail):
    try:
        publish_year = soup_detail.find("nobr", {"class":"greyText"}).text.replace("\n","").replace(")","").split()
        publish_year = publish_year[-1]
    except:
        publish_year = np.nan
    return publish_year

# get award
def get_award(soup_detail):
    try:
        award = soup_detail.find("div", {"itemprop":"awards"}).text.replace("\n","")
    except:
        award = np.nan
    return award

# get genres
def get_genres(soup_detail):
    try:
        genres = soup_detail.find_all(class_="actionLinkLite bookPageGenreLink")
        genres = genres[:3]
        genres = [genre.get_text() for genre in genres]
    except:
        genres = np.nan
    return genres

#get the book reviews

def get_review(soup_detail):
    try:
        review = soup_detail.find("meta", {"itemprop":"reviewCount"}).text.replace("\n","").split()
        review = review[0]
    except:
        review = np.nan
    return review
